# %% [markdown]
# <a href="https://colab.research.google.com/github/ellyasiml/CNN-LSTM-sentiment-analysis/blob/main/ta_capres_new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tweepy
import csv
import pandas as pd

api_key = "yxsQ1sN0Wijr8N7WHrIS0xKLT"
api_secret_key = "5nx00o7WE88Euz8U8cAgK1x5sYismeISMVy4PxiZDmPrHRZY5V"
access_token = "1572835106732941312-0XoNdKWHPa9GLf9R5IHFNokEUj7wOj"
access_token_secret = "xgxlOAb9qBVE7clmZSa9NoZhtqlM9lVx4ZgeKwJR1sAYt"

auth = tweepy.OAuthHandler(api_key, api_secret_key)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

search_keys = ["calon wakil presiden", "calon presiden", "capres OR cawapres"]

filename = "tweets.csv"

csvFile = open(filename, "w", newline="", encoding="utf-8")
csvWriter = csv.writer(csvFile)
csvWriter.writerow(["time", "id", "username", "location", "text"])

for search_key in search_keys:
    c = [] 
    i = [] 
    u = []
    l = [] 
    t = [] 
    
    for tweet in tweepy.Cursor(api.search_tweets, q=search_key, lang="id", tweet_mode="extended").items():
        print(search_key, tweet.created_at, tweet.id, tweet.user.name, tweet.user.location, tweet.full_text)
        c.append(tweet.created_at)
        i.append(tweet.id)
        u.append(tweet.user.name)
        l.append(tweet.user.location)
        text = tweet.full_text.encode('utf-8', errors='ignore').decode('utf-8')
        t.append(text)
        tweets = [tweet.created_at, tweet.id, tweet.user.name, tweet.user.location, text]
        csvWriter.writerow(tweets)
    
dictTweets = {"time": c, "id": i, "username": u, "location": l, "text": t}
df = pd.DataFrame(dictTweets, columns=["time", "id", "username", "location", "text"])
df.to_csv(filename, index=False, mode="a", header=False)  # append to existing CSV file
# Out:
# WARNING:tweepy.api:Rate limit reached. Sleeping for: 721
# calon wakil presiden 2023-05-09 06:34:13+00:00 1655823468812963840 Rajendra  Ia menambahka, nama-nama lain yang beredar sebagai calon wakil presiden pada survei kali ini angkanya diketahui lebih rendah. #AllInPrabowo #IkutPakde Prabowo Subianto
# calon wakil presiden 2023-05-09 06:31:40+00:00 1655822826732134400 Rajendra  Dalam kesempatan ini, LSI juga merilis temuan mereka tentang hasil jajak pendapat pemilihan Calon Wakil Presiden (Cawapres) 2024 secara semi terbuka. #AllInPrabowo #IkutPakde Prabowo Subianto
# calon wakil presiden 2023-05-09 06:27:50+00:00 1655821864378462209 lintang anggraeni  Saat ini ada 575 kursi di parlemen sehingga pasangan calon presiden dan wakil presiden pada Pilpres 2024 harus memiliki dukungan minimal 115 kursi di DPR RI. #AllInPrabowo #IkutPakde Prabowo Subianto
# ...
